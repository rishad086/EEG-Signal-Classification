# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
EEG_data= pd.read_csv("new12.csv")
EEG_data.head()
# Out:
#   Unnamed: 0            0            1            2            3            4  \
# 0    EEG.AF3  4210.641113  4201.025879  4203.205078  4186.538574  4232.436035
# 1     EEG.F7  4179.102539  4188.717773  4182.820313  4168.717773  4216.922852
# 2     EEG.F3  4287.948730  4280.128418  4282.820313  4266.794922  4306.922852
# 3    EEG.FC5  4235.384766  4236.922852  4231.025879  4229.230957  4270.769043
# 4     EEG.T7  4207.948730  4209.615234  4207.820313  4202.179688  4217.436035
#
#              5            6            7            8  ...         2380  \
# 0  4212.436035  4232.692383  4218.333496  4207.179688  ...  4270.000000
# 1  4173.974121  4199.230957  4178.846191  4170.000000  ...  4249.615234
# 2  4282.948730  4302.820313  4286.282227  4278.589844  ...  4299.615234
# 3  4231.153809  4262.051270  4245.256348  4237.436035  ...  4292.307617
# 4  4209.743652  4215.512695  4215.256348  4206.538574  ...  4294.230957
#
#           2381         2382         2383         2384         2385  \
# 0  4259.102539  4292.051270  4263.717773  4271.025879  4258.974121
# 1  4231.538574  4279.230957  4229.102539  4239.871582  4242.051270
# 2  4282.436035  4310.769043  4286.666504  4292.436035  4282.307617
# 3  4272.820313  4320.128418  4276.794922  4283.717773  4290.000000
# 4  4272.820313  4298.205078  4276.666504  4284.871582  4286.666504
#
#           2386         2387         2388  2389
# 0  4261.666504  4262.563965  4262.692383     0
# 1  4236.922852  4243.333496  4250.769043     0
# 2  4288.077148  4290.128418  4283.846191     0
# 3  4286.282227  4286.282227  4287.307617     0
# 4  4281.794922  4284.743652  4298.974121     0
#
# [5 rows x 2391 columns]

# %%
# from sklearn.feature_selection import VarianceThreshold
# var_thres=VarianceThreshold(threshold=0)
# var_thres.fit(EEG_data)

# %%
# var_thres.get_support()

# %%
#cheak for duplixated features in the training set
# dup_fet = []
# for i in range(0,len(EEG_data.columns)):
#     col_1=EEG_data.columns[i]
#     for col_2 in EEG_data.columns[i + 1:]:
#         if EEG_data[col_1].equals(EEG_data[col_2]):
#             dup_fet.append(col_2)
# len(dup_fet)

# %%
# cols_remove=EEG_data.columns.tolist()[0:1]

# %%
# cols_remove
# Out:
# ['Unnamed: 0']

# %%
# EEG_data=EEG_data.loc[:, ~EEG_data.columns.isin(cols_remove)]
# EEG_data.head()
# Out:
#        EEG.AF3       EEG.F7       EEG.F3      EEG.FC5       EEG.T7  \
# 0  4210.641113  4179.102539  4287.948730  4235.384766  4207.948730
# 1  4201.025879  4188.717773  4280.128418  4236.922852  4209.615234
# 2  4203.205078  4182.820313  4282.820313  4231.025879  4207.820313
# 3  4186.538574  4168.717773  4266.794922  4229.230957  4202.179688
# 4  4232.436035  4216.922852  4306.922852  4270.769043  4217.436035
#
#         EEG.P7       EEG.O1       EEG.O2       EEG.P8       EEG.T8  \
# 0  4165.000000  4135.897461  4170.000000  4155.384766  4157.179688
# 1  4152.436035  4130.128418  4149.487305  4149.487305  4157.820313
# 2  4172.436035  4131.538574  4147.948730  4131.666504  4131.666504
# 3  4155.384766  4128.333496  4151.666504  4136.666504  4134.230957
# 4  4166.538574  4155.897461  4162.820313  4143.461426  4154.487305
#
# EEG.F8   4369.358887  4395.641113  4375.000000  4374.743652  4398.461426  ...
# EEG.AF4  4485.512695  4505.128418  4486.666504  4483.589844  4545.897461  ...
#
#                 2379         2380         2381         2382         2383  \
# EEG.AF3  4262.563965  4270.000000  4259.102539  4292.051270  4263.717773
# EEG.F7   4229.871582  4249.615234  4231.538574  4279.230957  4229.102539
# EEG.F3   4291.538574  4299.615234  4282.436035  4310.769043  4286.666504
# EEG.FC5  4278.974121  4292.307617  4272.820313  4320.128418  4276.794922
# EEG.T7   4286.025879  4294.230957  4272.820313  4298.205078  4276.666504
# EEG.P7   4199.743652  4216.922852  4202.051270  4220.641113  4225.256348
# EEG.O1   4212.179688  4218.717773  4214.358887  4223.974121  4221.922852
# EEG.O2   4214.358887  4222.692383  4221.282227  4217.820313  4224.871582
# EEG.P8   4186.922852  4186.666504  4192.307617  4185.256348  4194.487305
# EEG.T8   4189.487305  4199.615234  4200.769043  4206.025879  4208.333496
# EEG.FC6  4472.051270  4478.461426  4483.846191  4502.051270  4501.282227
# EEG.F4   4385.384766  4379.743652  4375.641113  4396.794922  4385.897461
# EEG.F8   4363.205078  4367.179688  4362.051270  4374.102539  4354.615234
# EEG.AF4  4428.974121  4428.717773  4416.025879  4436.025879  4426.794922
#
#                 2384         2385         2386         2387         2388
# EEG.AF3  4271.025879  4258.974121  4261.666504  4262.563965  4262.692383
# EEG.F7   4239.871582  4242.051270  4236.922852  4243.333496  4250.769043
# EEG.F3   4292.436035  4282.307617  4288.077148  4290.128418  4283.846191
# EEG.FC5  4283.717773  4290.000000  4286.282227  4286.282227  4287.307617
# EEG.T7   4284.871582  4286.666504  4281.794922  4284.743652  4298.974121
# EEG.P7   4240.000000  4236.666504  4220.641113  4236.153809  4249.615234
# EEG.O1   4211.666504  4220.000000  4213.077148  4218.461426  4210.769043
# EEG.O2   4224.615234  4216.666504  4224.743652  4224.230957  4210.384766
# EEG.P8   4206.794922  4194.102539  4209.358887  4196.922852  4195.256348
# EEG.T8   4212.051270  4192.436035  4208.974121  4191.153809  4196.922852
# EEG.FC6  4500.000000  4471.282227  4482.948730  4476.538574  4489.871582
# EEG.F4   4385.769043  4375.512695  4388.333496  4383.333496  4370.641113
# EEG.F8   4380.128418  4358.589844  4365.512695  4356.410156  4366.153809
# EEG.AF4  4430.897461  4417.692383  4432.948730  4428.846191  4427.820313
#
# [14 rows x 2389 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y ,test_size = 0.2)
x_train.shape
x_test.shape
y_train.shape
y_test.shape
# Out:
# (84,)

# %%
# k=x_train.T
# k

# cols_remove=k.columns.tolist()[0:1]

# k=k.loc[:, ~k.columns.isin(cols_remove)]
# k.head()
# k=k.T
# k.head()

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((336, 2390), (336,), (84, 2390), (84,))

# %%
# from sklearn.feature_selection import VarianceThreshold
# Qusicons_filter = VarianceThreshold(threshold=0.01)

# %%
# X_train_Qusicons = Qusicons_filter.fit_transform(x0)
# print("Non Quasi-constant train shape :",X_train_Qusicons.shape)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,15))
cor = x_train.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.CMRmap_r)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16080\3729123548.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = x_train.corr()

# %% [markdown]
# ## threshold at = 85% and correlated = 3 var

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features0 = correlation(x_train,0.85)
len(set(corr_features0))
print("corr_features0: ",len(set(corr_features0)))
print("corr_features0: ",corr_features0)

# %%
x_train.shape
# Out:
# (55064, 14)

# %%
x_train_noncorr0=x_train.drop(corr_features0,axis=1)

# %%
x_train_noncorr0.shape
# Out:
# (55064, 11)

# %%
x_test_noncorr0=x_test.drop(corr_features0,axis=1)

# %%
x_test_noncorr0.shape
# Out:
# (13767, 11)

# %%
from datetime import datetime
start = datetime.now()
from sklearn.ensemble import RandomForestClassifier
RFC= RandomForestClassifier(random_state=1)
RFC.fit(x_train_noncorr0,y_train)
end = datetime.now()
print("Total execution time: ",end-start)
# Out:
# Total execution time:  0:00:22.204190

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
y_prec = RFC.predict(x_test_noncorr)

print("Accuracy score on 11 independet var :",accuracy_score(y_test,y_prec)*100)
# Out:
# Accuracy score on 11 independet var : 93.59337546306385

# %%
print("Confusion Matrix:\n",confusion_matrix(y_test,y_prec))
# Out:
# Confusion Matrix:
#  [[ 2226   663]
#  [  219 10659]]

# %%
print("Correct Predictions are:",sum(y_test == y_prec))
print("InCorrect Predictions are:",sum(y_test != y_prec))

print("Accuracy :",sum(y_test==y_prec)/len(y_prec)*100)
# Out:
# Correct Predictions are: 12885
# InCorrect Predictions are: 882
# Accuracy : 93.59337546306385

# %%
print("Classification Report:\n",classification_report(y_test,y_prec,digits=4))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9104    0.7705    0.8346      2889
#            1     0.9414    0.9799    0.9603     10878
#
#     accuracy                         0.9359     13767
#    macro avg     0.9259    0.8752    0.8975     13767
# weighted avg     0.9349    0.9359    0.9339     13767

# %% [markdown]
# ## threshold at = 90% and correlated = 1 var

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features1 = correlation(x_train,0.90)
len(set(corr_features1))
print("corr_features1: ",len(set(corr_features1)))
print("corr_features1: ",corr_features1)
# Out:
# corr_features1:  0
# corr_features1:  set()

# %%
x_train_noncorr1=x_train.drop(corr_features1,axis=1)
x_train_noncorr1
# Out:
#            EEG.AF3       EEG.F7       EEG.F3      EEG.FC5       EEG.T7  \
# 35053  4325.769043  4302.563965  4337.179688  4327.820313  4341.025879
# 48750  4261.922852  4249.615234  4282.820313  4279.487305  4302.307617
# 42630  4303.333496  4297.692383  4323.717773  4321.410156  4336.410156
# 52482  4372.051270  4176.282227  4288.205078  4261.410156  4244.615234
# 58896  4327.051270  4291.410156  4357.563965  4310.512695  4321.282227
# ...            ...          ...          ...          ...          ...
# 39271  4266.282227  4234.230957  4291.538574  4272.179688  4297.820313
# 55304  4234.230957  4192.051270  4271.922852  4269.102539  4248.717773
# 7943   4250.769043  4287.307617  4270.512695  4295.256348  4302.820313
# 1544   4240.512695  4214.871582  4283.077148  4248.717773  4258.846191
# 28076  4282.307617  4266.922852  4297.436035  4296.025879  4302.179688
#
#             EEG.P7       EEG.O1       EEG.O2       EEG.P8       EEG.T8
# 40889  4451.922852  4375.512695  4342.436035  4399.230957
# 47474  4479.358887  4393.205078  4370.384766  4433.333496
# 49090  4511.794922  4428.974121  4387.307617  4445.769043
# 31485  4459.871582  4391.153809  4353.717773  4420.256348
# 49818  4468.461426  4377.692383  4358.974121  4420.769043
#
# [13767 rows x 14 columns]

# %%
from datetime import datetime
start1 = datetime.now()
from sklearn.ensemble import RandomForestClassifier
RFC1= RandomForestClassifier(random_state=1)
RFC1.fit(x_train_noncorr1,y_train)
end1 = datetime.now()
print("Total execution time: ",end1-start1)
# Out:
# Total execution time:  0:00:22.371717

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
y_prec1 = RFC1.predict(x_test_noncorr1)

print("Accuracy score on 13 independet var :",accuracy_score(y_test,y_prec1)*100)
# Out:
# Accuracy score on 13 independet var : 94.2906951405535

# %%
print("Confusion Matrix:\n",confusion_matrix(y_test,y_prec1))
# Out:
# Confusion Matrix:
#  [[ 2293   596]
#  [  190 10688]]

# %%
print("Correct Predictions are:",sum(y_test == y_prec1))
print("InCorrect Predictions are:",sum(y_test != y_prec1))

print("Accuracy :",sum(y_test==y_prec1)/len(y_prec1)*100)
# Out:
# Correct Predictions are: 12981
# InCorrect Predictions are: 786
# Accuracy : 94.2906951405535

# %%
print("Classification Report:\n",classification_report(y_test,y_prec1,digits=4))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9235    0.7937    0.8537      2889
#            1     0.9472    0.9825    0.9645     10878
#
#     accuracy                         0.9429     13767
#    macro avg     0.9353    0.8881    0.9091     13767
# weighted avg     0.9422    0.9429    0.9413     13767

# %% [markdown]
# ## threshold at = 80% and correlated = 7 var

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features2 = correlation(x_train,0.80)
len(set(corr_features2))
print("corr_features2: ",len(set(corr_features2)))
print("corr_features2: ",corr_features2)
# Out:
# corr_features2:  7
# corr_features2:  {'EEG.F3', 'EEG.T8', 'EEG.O1', 'EEG.F4', 'EEG.T7', 'EEG.P7', 'EEG.P8'}

# %%
x_train_noncorr2=x_train.drop(corr_features2,axis=1)
x_train_noncorr2
# Out:
#            EEG.AF3       EEG.F7      EEG.FC5       EEG.O2      EEG.FC6  \
# 35053  4325.769043  4302.563965  4327.820313  4288.717773  4524.102539
# 48750  4261.922852  4249.615234  4279.487305  4243.205078  4450.384766
# 42630  4303.333496  4297.692383  4321.410156  4277.820313  4511.025879
# 52482  4372.051270  4176.282227  4261.410156  4170.897461  4528.846191
# 58896  4327.051270  4291.410156  4310.512695  4136.282227  4431.794922
# ...            ...          ...          ...          ...          ...
# 39271  4266.282227  4234.230957  4272.179688  4244.230957  4473.205078
# 55304  4234.230957  4192.051270  4269.102539  4172.692383  4567.820313
# 7943   4250.769043  4287.307617  4295.256348  4198.077148  4511.025879
# 1544   4240.512695  4214.871582  4248.717773  4200.000000  4510.000000
# 28076  4282.307617  4266.922852  4296.025879  4250.512695  4462.563965
#
#             EEG.F8      EEG.AF4
# 35053  4400.256348  4484.871582
# 48750  4341.282227  4403.717773
# 42630  4380.641113  4450.512695
# 52482  4377.436035  4490.128418
# 58896  4320.128418  4271.794922
# ...            ...          ...
# 39271  4356.666504  4417.692383
# 55304  4377.820313  4470.769043
# 7943   4377.820313  4439.358887
# 1544   4383.205078  4443.461426
# 28076  4372.820313  4414.102539
#
# [55064 rows x 7 columns]

# %%
x_test_noncorr2=x_test.drop(corr_features2,axis=1)
x_test_noncorr2
# Out:
#            EEG.AF3       EEG.F7      EEG.FC5       EEG.O2      EEG.FC6  \
# 66604  4310.000000  4305.384766  4320.256348  4298.846191  4430.512695
# 23167  4254.230957  4270.128418  4279.743652  4273.077148  4449.743652
# 59144  4183.974121  4173.333496  4149.871582  3837.051270  4193.974121
# 62159  4331.282227  4341.794922  4398.974121  4263.846191  4465.128418
# 42559  4305.128418  4309.743652  4322.948730  4249.743652  4480.641113
# ...            ...          ...          ...          ...          ...
# 40889  4260.641113  4246.922852  4281.666504  4236.538574  4451.922852
# 47474  4280.256348  4263.333496  4295.128418  4251.282227  4479.358887
# 49090  4303.205078  4300.641113  4319.743652  4284.102539  4511.794922
# 31485  4276.666504  4261.538574  4282.692383  4246.410156  4459.871582
# 49818  4282.051270  4269.487305  4281.794922  4242.948730  4468.461426
#
#             EEG.F8      EEG.AF4
# 66604  4373.205078  4395.128418
# 23167  4364.871582  4385.128418
# 59144  4203.205078  4215.641113
# 62159  4404.358887  4526.794922
# 42559  4366.922852  4443.333496
# ...            ...          ...
# 40889  4342.436035  4399.230957
# 47474  4370.384766  4433.333496
# 49090  4387.307617  4445.769043
# 31485  4353.717773  4420.256348
# 49818  4358.974121  4420.769043
#
# [13767 rows x 7 columns]

# %%
from datetime import datetime
start2 = datetime.now()
from sklearn.ensemble import RandomForestClassifier
RFC2= RandomForestClassifier(random_state=1)
RFC2.fit(x_train_noncorr2,y_train)
end2 = datetime.now()
print("Total execution time: ",end2-start2)
# Out:
# Total execution time:  0:00:15.214885

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
y_prec2 = RFC2.predict(x_test_noncorr2)

print("Accuracy score on 13 independet var :",accuracy_score(y_test,y_prec2)*100)
# Out:
# Accuracy score on 13 independet var : 91.91544998910437

# %%
print("Confusion Matrix:\n",confusion_matrix(y_test,y_prec2))
# Out:
# Confusion Matrix:
#  [[ 2085   804]
#  [  309 10569]]

# %%
print("Correct Predictions are:",sum(y_test == y_prec2))
print("InCorrect Predictions are:",sum(y_test != y_prec2))

print("Accuracy :",sum(y_test==y_prec2)/len(y_prec2)*100)
# Out:
# Correct Predictions are: 12654
# InCorrect Predictions are: 1113
# Accuracy : 91.91544998910437

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.imagenet_utils import preprocess_input
import math
batch_size = 30
img_size = (150,150)

root_dir = "D:/EEG/Zero/"


img_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

datagen = img_gen.flow_from_directory(root_dir,
                                        target_size=(img_size, img_size),
                                        batch_size=batch_size,
                                        class_mode=None,
                                        shuffle=False)
num_images = len(datagen.filenames)
num_epochs = int(math.ceil(num_images / batch_size))

feature_list = model.predict_generator(datagen, num_epochs,verbose = 1)

feature_list
# Out:
# Found 0 images belonging to 0 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 20
#      17 num_images = len(datagen.filenames)
#      18 num_epochs = int(math.ceil(num_images / batch_size))
# ---> 20 feature_list = model.predict_generator(datagen, num_epochs,verbose = 1)
#      22 feature_list
#
# NameError: name 'model' is not defined
